# %%
import pandas as pd

pd.set_option('display.max_row', 1000)

df = pd.read_csv("MRCONSO.RRF", names=['CUI', 'LAT', 'TS', 'LUI', 'STT', 'SUI','ISPREF','AUI','SAIUI',
                                      'SCUI','SDUI','SAB','TTY','CODE','STR','SRL','SUPPRESS','CVF','UNK'],delimiter = '|')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9,10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         CUI  LAT TS       LUI STT       SUI ISPREF        AUI  SAIUI  \
# 0  C0000005  ENG  P  L0000005  PF  S0007492      Y  A26634265    NaN
# 1  C0000005  ENG  S  L0270109  PF  S0007491      Y  A26634266    NaN
# 2  C0000005  FRE  P  L6220710  PF  S7133957      Y  A13433185    NaN
# 3  C0000005  FRE  S  L6215648  PF  S7133916      Y  A27488794    NaN
# 4  C0000005  FRE  S  L6215656  PF  S7133956      Y  A27614225    NaN
#
#        SCUI     SDUI     SAB  TTY     CODE  \
# 0  M0019694  D012711     MSH  PEP  D012711
# 1  M0019694  D012711     MSH   ET  D012711
# 2  M0019694  D012711  MSHFRE  PEP  D012711
# 3  M0019694  D012711  MSHFRE   ET  D012711
# 4  M0019694  D012711  MSHFRE   ET  D012711
#
#                                                  STR  SRL SUPPRESS    CVF  UNK
# 0                     (131)I-Macroaggregated Albumin    0        N  256.0  NaN
# 1                                         (131)I-MAA    0        N  256.0  NaN
# ...

# %%
df.iloc[10:20, 2:7]
# Out:
#     P  L0000005  PF  S0007492  Y
# 10  S  L0000035  PF  S0007560  N
# 11  S  L0000035  PF  S0007560  Y
# 12  S  L0000035  VO  S1357276  Y
# 13  S  L0000038  PF  S0007563  N
# 14  S  L0000038  PF  S0007563  Y
# 15  S  L0000038  VO  S1357295  Y
# 16  S  L0012507  PF  S0033298  N
# 17  S  L0012507  PF  S0033298  N
# 18  S  L0012507  PF  S0033298  N
# 19  S  L0012507  PF  S0033298  N

# %%
df.count()
# Out:
# CUI         14608808
# LAT         14608808
# TS          14608808
# LUI         14608808
# STT         14608808
# SUI         14608808
# ISPREF      14608808
# AUI         14608808
# SAIUI        3212644
# SCUI        10897950
# SDUI         3772042
# SAB         14608808
# TTY         14599740
# CODE        14608796
# STR         14608787
# SRL         14608808
# SUPPRESS    14608808
# CVF          5290801
# UNK                0
# dtype: int64

# %%
df[['SAB', 'LAT']].groupby('SAB').count().sort_values(['LAT'])
# Out:
#                      LAT
# SAB
# MTHCMSFRF              8
# NCI_ZFin              25
# NCI_PI-RADS           39
# MCM                   43
# MTHICPC2EAE           53
# MVX                   77
# ULT                   84
# NCI_DICOM            114
# MTHICPC2ICD10AE      137
# NCI_JAX              156
# SOP                  162
# NCI_PID              169
# NCI_INC              201
# NCI_GAIA             208
# NCI_NCI-HL7          244
# DDB                  256
# RAM                  258
# PNDS                 262
# NCI_KEGG             278
# NCI_RENI             310
# NCI_BioC             336
# PPAC                 380
# CCC                  410
# NCI_CTEP-SDC         463
# NCI_CPTAC            463
# AOT                  471
# ICPCHEB              485
# NCI_ICH              500
# MTHHH                529
# NCI_NCPDP            544
# OMS                  554
# CVX                  642
# ICPC2EDUT            685
# AIR                  685
# ICPCBAQ              695
# ...

# %%
pref_names = df[(df['LAT']=='ENG') & (df['ISPREF']=='Y') & (df['TS']=='P') & (df['STT'] =='PF')]

# %%
pref_names
# Out:
#                CUI  LAT TS        LUI STT        SUI ISPREF        AUI  \
# 0         C0000005  ENG  P   L0000005  PF   S0007492      Y  A26634265
# 7         C0000039  ENG  P   L0000039  PF  S17175117      Y  A28572604
# 66        C0000052  ENG  P   L0000052  PF   S0007584      Y   A0016536
# 145       C0000074  ENG  P   L0000074  PF   S0007615      Y  A26606894
# 153       C0000084  ENG  P   L0000084  PF   S0007627      Y   A0016576
# 212       C0000096  ENG  P   L0000096  PF   S0463366      Y   A0526764
# 255       C0000097  ENG  P   L0000097  PF   S0007641      Y   A0016587
# 299       C0000098  ENG  P   L0000098  PF   S0007643      Y   A0016589
# 342       C0000102  ENG  P   L0000102  PF   S0007647      Y   A0016592
# 410       C0000103  ENG  P   L0000103  PF   S0007648      Y   A0016593
# 448       C0000107  ENG  P   L0000107  PF   S0007657      Y   A0016602
# 489       C0000119  ENG  P   L0000119  PF   S0007694      Y   A0016627
# ...
