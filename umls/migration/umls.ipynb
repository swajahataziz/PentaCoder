# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series([1,3,4, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
file = "Downloads/MRCONSO.RRF"

# %%
file
# Out:
# 'Users/wajahat/Downloads/MRCONSO.RRF'

# %%
df = pd.read_csv("MRCONSO.RRF", names=['CUI', 'LAT', 'TS', 'LUI', 'STT', 'SUI','ISPREF','AUI','SAIUI',
                                       'SCUI','SDUI','SAB','TTY','CODE','STR','SRL','SUPPRESS','CVF','UNK'],delimiter = '|')'
# Out:
#   File "<ipython-input-27-c7d238181ce9>", line 2
#     'SCUI','SDUI','SAB','TTY','CODE','STR','SRL','SUPPRESS','CVF','UNK'],delimiter = '|')'
#                                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
dataset.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>C0000005</th>
#       <th>ENG</th>
#       <th>P</th>
#       <th>L0000005</th>
#       <th>PF</th>
#       <th>S0007492</th>
#       <th>Y</th>
#       <th>A26634265</th>
#       <th>Unnamed: 8</th>
#       <th>M0019694</th>
#       <th>D012711</th>
#       <th>MSH</th>
#       <th>PEP</th>
#       <th>D012711.1</th>
#       <th>(131)I-Macroaggregated Albumin</th>
#       <th>0</th>
#       <th>N</th>
#       <th>256</th>
#       <th>Unnamed: 18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>C0000005</td>
#       <td>ENG</td>
#       <td>S</td>
#       <td>L0270109</td>
#       <td>PF</td>
#       <td>S0007491</td>
#       <td>Y</td>
#       <td>A26634266</td>
#       <td>NaN</td>
#       <td>M0019694</td>
#       <td>D012711</td>
#       <td>MSH</td>
#       <td>ET</td>
#       <td>D012711</td>
#       <td>(131)I-MAA</td>
#       <td>0</td>
#       <td>N</td>
#       <td>256.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C0000005</td>
#       <td>FRE</td>
#       <td>P</td>
#       <td>L6220710</td>
#       <td>PF</td>
#       <td>S7133957</td>
#       <td>Y</td>
#       <td>A13433185</td>
#       <td>NaN</td>
#       <td>M0019694</td>
#       <td>D012711</td>
#       <td>MSHFRE</td>
#       <td>PEP</td>
#       <td>D012711</td>
#       <td>Macroagrégats d'albumine marquée à l'iode 131</td>
#       <td>3</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C0000005</td>
#       <td>FRE</td>
#       <td>S</td>
#       <td>L6215648</td>
#       <td>PF</td>
#       <td>S7133916</td>
#       <td>Y</td>
#       <td>A27488794</td>
#       <td>NaN</td>
#       <td>M0019694</td>
#       <td>D012711</td>
#       <td>MSHFRE</td>
#       <td>ET</td>
#       <td>D012711</td>
#       <td>MAA-I 131</td>
#       <td>3</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C0000005</td>
#       <td>FRE</td>
#       <td>S</td>
#       <td>L6215656</td>
#       <td>PF</td>
#       <td>S7133956</td>
#       <td>Y</td>
#       <td>A27614225</td>
#       <td>NaN</td>
#       <td>M0019694</td>
#       <td>D012711</td>
#       <td>MSHFRE</td>
#       <td>ET</td>
#       <td>D012711</td>
#       <td>Macroagrégats d'albumine humaine marquée à l'i...</td>
#       <td>3</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C0000039</td>
#       <td>CZE</td>
#       <td>P</td>
#       <td>L6742182</td>
#       <td>PF</td>
#       <td>S7862052</td>
#       <td>Y</td>
#       <td>A13042554</td>
#       <td>NaN</td>
#       <td>M0023172</td>
#       <td>D015060</td>
#       <td>MSHCZE</td>
#       <td>MH</td>
#       <td>D015060</td>
#       <td>1,2-dipalmitoylfosfatidylcholin</td>
#       <td>3</td>
#       <td>N</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>
